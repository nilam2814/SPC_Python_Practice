# %% [markdown]
# # Basic List Operations

# %% [markdown]
# 1. Create a list of 5 numbers and add a new number to the end.

# %%
lst=[10,20,30,40,50]
lst
lst.insert(6,60)
lst
# Out:
# [10, 20, 30, 40, 50, 60]

# %% [markdown]
# 2. Make a list of fruits and insert a fruit at the second position.

# %%
fruits=["mango","banana","strawberry"]
print(fruits)
fruits.insert(1,"apple")
fruits
# Out:
# ['mango', 'banana', 'strawberry']
# ['mango', 'apple', 'banana', 'strawberry']

# %% [markdown]
# 3. Create a list of names and remove one name from the list.

# %%
names=["nilam","raj","ayesha"]
names
names.remove("raj")
names
# Out:
# ['nilam', 'ayesha']

# %% [markdown]
# 4. Create a list of 4 items and change the value at index 2.

# %%
items=["bulb","charger","laptop"]
items[2]="mobile"
items
# Out:
# ['bulb', 'charger', 'mobile']

# %% [markdown]
# 5. Make a list of numbers and print only the first three elements.

# %%
num=[1,2,3,4,5]
num[0:3]
# Out:
# [1, 2, 3]

# %% [markdown]
# 6. Create a list of colors and find the index of a specific color.

# %%
colors=["pink","black","blue","green"]
colors
colors.index("blue")
# Out:
# 2

# %% [markdown]
# 7. Create a list of 10 numbers and print how many times “5” appears.

# %%
numbers=[1,3,5,2,5,6,7,5,9,5]
numbers
numbers.count(5)
# Out:
# 4

# %% [markdown]
# 8. Make a list of 6 items and delete the item at index 3.

# %%
itm=["abc","xyz","def","num","val","err"]
itm
itm.pop(3)
itm
# Out:
# ['abc', 'xyz', 'def', 'val', 'err']

# %% [markdown]
# 9. Create a list of animals and add three more animals using extend().

# %%
animals=["cat","dog","elephant"]
animals
animals.extend(["horse","pig","lion"])
animals
# Out:
# ['cat', 'dog', 'elephant', 'horse', 'pig', 'lion']

# %% [markdown]
# 10. Create a list and remove the last item using pop().

# %%
lst=[10,40,50,30]
lst
lst.pop()
# Out:
# 30

# %% [markdown]
# 11. Create a list of prices and sort them in ascending order.

# %%
prices=[100,150.3,200.1,400]
prices
prices.sort()
prices
# Out:
# [100, 150.3, 200.1, 400]

# %% [markdown]
# 12. Make a list of countries and reverse the order of the list.

# %%
country=["india","china","USA","UK"]
country.reverse()
country
# Out:
# ['UK', 'USA', 'china', 'india']

# %% [markdown]
# 13. Create a list of words and check if “apple” is in the list.

# %%
list=["guava","orange","apple","mango"]
"apple" in list
# Out:
# True

# %% [markdown]
# 14. Create a list of numbers and print the largest and smallest number.

# %%
num=[11,23,21,14,43,56,67]
print(min(num))
print(max(num))
# Out:
# 11
# 67

# %% [markdown]
# 15. Make a list of 5 items and print each item using a loop.

# %%
list=[24,45,23,56,18,20]
for i in list:
    print(i)
# Out:
# 24
# 45
# 23
# 56
# 18
# 20

# %% [markdown]
# 16. Create two lists and combine them into one list.

# %%
lst1=[1,2,3]
lst2=[6,4,5]
lst1.extend(lst2)
lst1
# Out:
# [1, 2, 3, 6, 4, 5]

# %% [markdown]
# 17. Make a list and replace the last item with a new value.

# %%
num= [1,5,3,6,7,8]
num[-1]= 0
num
# Out:
# [1, 5, 3, 6, 7, 0]

# %% [markdown]
# 18. Create a list of numbers and print only the even numbers.

# %%
lst1=[23,22,20,31,41,55,40,44]

for l in lst1:
    if l%2==0:
        print(l)
# Out:
# 22
# 20
# 40
# 44

# %% [markdown]
# 19. Create a list and clear all items from the list.

# %%
lst=[3,2,4,5,6]
lst
lst.clear()

# %% [markdown]
# 20. Create a list of 5 values and copy it into another list.

# %%
list1=[10,30,40,60,20]
list1
list2=list1.copy()
list2
# Out:
# [10, 30, 40, 60, 20]
